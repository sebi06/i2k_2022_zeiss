# %%
# Install czmodel and dependencies
! pip install --upgrade pip
! pip install "czmodel>=3.0,<4.0"
! pip install scikit-image xmltodict
! pip install onnxruntime
# Out:
# Requirement already satisfied: pip in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (22.0.4)
# Requirement already satisfied: czmodel<4.0,>=3.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (3.1.0)
# Requirement already satisfied: onnx in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel<4.0,>=3.0) (1.11.0)
# Requirement already satisfied: numpy in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel<4.0,>=3.0) (1.22.3)
# Requirement already satisfied: tf2onnx in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel<4.0,>=3.0) (1.9.3)
# Requirement already satisfied: tensorflow!=2.1,<3,>=2 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel<4.0,>=3.0) (2.8.0)
# Requirement already satisfied: defusedxml in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel<4.0,>=3.0) (0.7.1)
# Requirement already satisfied: xmltodict in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel<4.0,>=3.0) (0.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (0.25.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (2.8.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (3.20.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (1.44.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (3.3.0)
# Requirement already satisfied: setuptools in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (61.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (4.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (1.1.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (1.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (1.13.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (2.8.0.dev2021122109)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (3.6.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (0.5.3)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (1.12)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (14.0.1)
# Requirement already satisfied: requests in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tf2onnx->czmodel<4.0,>=3.0) (2.27.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from astunparse>=1.6.0->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (2.1.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (2.6.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (0.4.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from requests->tf2onnx->czmodel<4.0,>=3.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from requests->tf2onnx->czmodel<4.0,>=3.0) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from requests->tf2onnx->czmodel<4.0,>=3.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from requests->tf2onnx->czmodel<4.0,>=3.0) (2021.10.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel<4.0,>=3.0) (3.2.0)
# Requirement already satisfied: scikit-image in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (0.19.2)
# Requirement already satisfied: xmltodict in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from scikit-image) (1.22.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from scikit-image) (2022.4.26)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from scikit-image) (2.9.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from scikit-image) (1.7.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from scikit-image) (21.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from scikit-image) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from scikit-image) (8.4.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from scikit-image) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from packaging>=20.0->scikit-image) (3.0.4)
# Requirement already satisfied: onnxruntime in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (1.11.1)
# Requirement already satisfied: protobuf in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from onnxruntime) (3.20.1)
# Requirement already satisfied: flatbuffers in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from onnxruntime) (1.12)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from onnxruntime) (1.22.3)
# Requirement already satisfied: czmodel in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (3.1.0)
# Requirement already satisfied: onnx in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel) (1.11.0)
# Requirement already satisfied: xmltodict in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel) (0.12.0)
# Requirement already satisfied: defusedxml in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel) (0.7.1)
# Requirement already satisfied: tensorflow!=2.1,<3,>=2 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel) (2.8.0)
# Requirement already satisfied: tf2onnx in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel) (1.9.3)
# Requirement already satisfied: numpy in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from czmodel) (1.22.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (4.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (3.3.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (2.8.0.dev2021122109)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (1.44.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (3.20.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (1.13.3)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (1.0.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (0.25.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (1.16.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (0.5.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (3.6.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (1.1.0)
# Requirement already satisfied: setuptools in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (61.2.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (14.0.1)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorflow!=2.1,<3,>=2->czmodel) (1.12)
# Requirement already satisfied: requests in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tf2onnx->czmodel) (2.27.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from astunparse>=1.6.0->tensorflow!=2.1,<3,>=2->czmodel) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (2.1.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (2.6.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (0.4.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from requests->tf2onnx->czmodel) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from requests->tf2onnx->czmodel) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from requests->tf2onnx->czmodel) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from requests->tf2onnx->czmodel) (3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\m1srh\miniconda3\envs\napari_czmodel\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow!=2.1,<3,>=2->czmodel) (3.2.0)

# %%
# This can be used to switch on/off warnings
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %% [markdown]
# # Simple TF2 + Keras model for segmentation (to detect cell nuclei)
# This notebook the entire workflow of training an ANN with [TensorFlow 2](https://www.tensorflow.org/) using the keras API and exporting the trained model to the [CZANN format](https://pypi.org/project/czmodel/) to be ready for use within the [Intellesis](https://www.zeiss.de/mikroskopie/produkte/mikroskopsoftware/zen-intellesis-image-segmentation-by-deep-learning.html) infrastructure.
#
# * The trained model is rather simple (for demo purposes) and trained on a small test dataset.
# * **Therefore, this notebook is meant to be understood as a guide for exporting trained models.**
# * **The notebook does not provide instructions how train a model correctly.**

# %% [markdown]
# ## Imports

# %%
# Required imports to train a simple TF2 + Keras model for segmentation and package it as CZANN.
# The CZANN can then be imported in ZEN and used for segmentation and image analysis workflows.

# General imports
import os
import tensorflow as tf
import numpy as np
import tempfile
from pathlib import Path
import onnxruntime as onnx_rt

# Function provided by the PyPI package called czmodel (by ZEISS)
from czmodel.model_metadata import ModelMetadata, ModelSpec, ModelType
from czmodel.legacy_model_metadata import ModelMetadata as LegacyModelMetadata, ModelSpec as LegacyModelSpec
from czmodel import DefaultConverter, LegacyConverter
from czmodel.util.transforms import Shift, Scale

# %%
# Optional: suppress TF warnings
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
print(tf.version.GIT_VERSION, tf.__version__)
# Out:
# v2.8.0-rc1-32-g3f878cff5b6 2.8.0

# %% [markdown]
# ## Training Pipeline
# This section describes a simple training procedure that creates a trained Keras model.
#
# * Therefore, it only represents the custom training procedure
# * Such procedure will vary from case to case and will contain more sophisticated ways to generate an optimized Keras model

# %% [markdown]
# ### Define parameters for data loading

# %%
# Folder containing the input images
IMAGES_FOLDER = 'nucleus_data/images/'

# Folder containing the ground truth segmentation masks
# Mask images have one channel with a unique value of each class (0=background and 1=nucleus)
MASKS_FOLDER = 'nucleus_data/labels/'

# Path to the data on GitHub
GITHUB_TRAINING_DATA_PATH = 'https://raw.githubusercontent.com/zeiss-microscopy/OAD/master/Machine_Learning/notebooks/czmodel/nucleus_data.zip'
GITHUB_MODEL_CONVERSION_SPEC_PATH = 'https://raw.githubusercontent.com/zeiss-microscopy/OAD/master/Machine_Learning/notebooks/czmodel/model_conversion_spec.json'
GITHUB_onnx_inference_PATH = "https://raw.githubusercontent.com/sebi06/i2k_2022_zeiss/master/workshop/colab_notebooks/_onnx_inference.py"

# Define the number of input color channels
# This means that the inputs are grayscale with one channel only
CHANNELS = 1 

# The size of image crops to train the model with
CROP_SIZE = 512

# %% [markdown]
# ### Download data if it's not available on disk
# If this notebook is run e.g. as a colab notebook, it does not have access to the data folder on gitub via disk access.
# In that case we need to download the data from github first.

# %%
import requests

# Download training data
if not (os.path.isdir(IMAGES_FOLDER) and os.path.isdir(MASKS_FOLDER)):
    compressed_data = './nucleus_data.zip'
    if not os.path.isfile(compressed_data):
        import io
        response = requests.get(GITHUB_TRAINING_DATA_PATH, stream=True)
        compressed_data = io.BytesIO(response.content)
        
    import zipfile
    with zipfile.ZipFile(compressed_data, 'r') as zip_accessor:
        zip_accessor.extractall('./')

def get_file_from_github(path, filename):
    # download file
    if not os.path.isfile(filename):
        response = requests.get(path, stream=True)
        with open(filename, 'wb') as handle:
            handle.write(response.content)
        
# download model conversion spec
get_file_from_github(GITHUB_MODEL_CONVERSION_SPEC_PATH, "model_conversion_spec.json")
        
# download _onnx_inference.py
get_file_from_github(GITHUB_onnx_inference_PATH, "_onnx_inference.py")

# %% [markdown]
# ### Read images
# This part contains the logic to read pairs of images and label masks for training

# %%
def order_unique_values(mask):
    for i, unique_value in enumerate(np.unique(mask)):
        mask[mask == unique_value] = i
    return mask

# %%
# Determine the paths of the input samples
sample_images = sorted([os.path.join(IMAGES_FOLDER, f) for f in os.listdir(IMAGES_FOLDER) 
                        if os.path.isfile(os.path.join(IMAGES_FOLDER, f))])

# Determine the paths of the corresponding masks
sample_masks = sorted([os.path.join(MASKS_FOLDER, f) for f in os.listdir(MASKS_FOLDER) 
                       if os.path.isfile(os.path.join(MASKS_FOLDER, f))])

# Load images as numpy arrays and scale to interval [0..1]
images_loaded = np.asarray(
    [
        tf.image.decode_image(
            tf.io.read_file(sample_path), channels=CHANNELS, dtype=tf.uint16
        ).numpy().astype(np.float32) / (2**16 - 1)
        for sample_path in sample_images
    ]
)

# %%
# Normalize images
images_mean = images_loaded.mean(axis=(0,1,2))
images_std = images_loaded.std(axis=(0,1,2))
images_loaded = (images_loaded - images_mean) / images_std

# %%
# Load labels as numpy arrays amd convert to one-hot representation
masks_loaded = np.asarray([
    tf.one_hot(
        tf.convert_to_tensor(
            order_unique_values(tf.image.decode_image(tf.io.read_file(sample_path), channels=1)[...,0].numpy())
        ), depth=2
    ).numpy()
    for sample_path in sample_masks
])

# %% [markdown]
# Remark: For details see [tf.one_hot](https://www.tensorflow.org/api_docs/python/tf/one_hot)
#
# `tf.one_hot creates X channels from X labels: 1 => [0.0, 1.0], 0 => [1.0, 0.0]`

# %% [markdown]
# ### Define a TensorFlow dataset to pre-process the images
# Since the dataset contains very large images we need to train on smaller crops in order to not exhaust the GPU memory

# %%
# Define a simple random crop transformation to train on smaller crops
def random_crop(image, mask, height, width):
    stacked = tf.concat([image, mask], axis=-1)
    stacked_cropped = tf.image.random_crop(
        stacked,
        size=tf.stack([height, width, tf.shape(image)[-1] + tf.shape(mask)[-1]], axis=0)
    )
    image_cropped = stacked_cropped[..., :tf.shape(image)[-1]]
    mask_cropped = stacked_cropped[..., tf.shape(image)[-1]:]
    return image_cropped, mask_cropped

# Define a TensorFlow dataset applying the random crop and batching the training data.
dataset = tf.data.Dataset.from_tensor_slices(
    ((images_loaded, masks_loaded))
).map(
    lambda x, y: random_crop(x, y, CROP_SIZE, CROP_SIZE)
).shuffle(10).batch(8)

# %% [markdown]
# ### Define a simple model
# This part defines a simple Keras model with two convolutional layers and softmax activation at the output node. It is also possible to add pre-processing layers to the model here.

# %%
# Define simple Keras model with two convolutional layers and softmax activation at the output node
model = tf.keras.models.Sequential(
    [
        tf.keras.layers.Conv2D(16, 3, padding='same'), 
        tf.keras.layers.Conv2D(2, 1, activation='softmax', padding='same')
    ]
)

# compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %% [markdown]
# ### Fit the model to the loaded data
# This part fits the model to the loaded data. In this test example we do not care about an actual evaluation of the model using validation and test datasets.

# %%
# define number of training epochs
NUM_EPOCHS = 25

# fit the model to the data
model.fit(dataset, epochs=NUM_EPOCHS)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 5s 143ms/step - loss: 0.5536 - categorical_accuracy: 0.9650
# Epoch 2/25
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5240 - categorical_accuracy: 0.9692
# Epoch 3/25
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4983 - categorical_accuracy: 0.9731
# Epoch 4/25
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4656 - categorical_accuracy: 0.9709
# Epoch 5/25
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4428 - categorical_accuracy: 0.9708
# Epoch 6/25
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4208 - categorical_accuracy: 0.9677
# Epoch 7/25
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3968 - categorical_accuracy: 0.9675
# Epoch 8/25
# 2/2 [==============================] - 0s 90ms/step - loss: 0.3732 - categorical_accuracy: 0.9707
# Epoch 9/25
# 2/2 [==============================] - 1s 34ms/step - loss: 0.3564 - categorical_accuracy: 0.9734
# Epoch 10/25
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3378 - categorical_accuracy: 0.9684
# Epoch 11/25
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3197 - categorical_accuracy: 0.9754
# Epoch 12/25
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3066 - categorical_accuracy: 0.9730
# Epoch 13/25
# 2/2 [==============================] - 0s 46ms/step - loss: 0.2932 - categorical_accuracy: 0.9725
# Epoch 14/25
# 2/2 [==============================] - 0s 54ms/step - loss: 0.2829 - categorical_accuracy: 0.9669
# Epoch 15/25
# 2/2 [==============================] - 0s 50ms/step - loss: 0.2645 - categorical_accuracy: 0.9735
# Epoch 16/25
# 2/2 [==============================] - 1s 22ms/step - loss: 0.2598 - categorical_accuracy: 0.9701
# Epoch 17/25
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2381 - categorical_accuracy: 0.9778
# Epoch 18/25
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2381 - categorical_accuracy: 0.9707
# Epoch 19/25
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2257 - categorical_accuracy: 0.9711
# Epoch 20/25
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2251 - categorical_accuracy: 0.9667
# Epoch 21/25
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2113 - categorical_accuracy: 0.9688
# Epoch 22/25
# 2/2 [==============================] - 0s 59ms/step - loss: 0.2028 - categorical_accuracy: 0.9718
# Epoch 23/25
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2077 - categorical_accuracy: 0.9691
# Epoch 24/25
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1918 - categorical_accuracy: 0.9730
# Epoch 25/25
# 2/2 [==============================] - 1s 67ms/step - loss: 0.1803 - categorical_accuracy: 0.9736

# %%
import matplotlib.pyplot as plt

# get an image and a mask from the dataset
for img, mask in dataset:

    #run the prediction and get the masks using argmax
    pred = model.predict(img)[0]
    pred = np.argmax(pred, axis=-1)

    # show some results
    img_scaled = img.numpy()[0] / img.numpy().max()
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
    fig.set_figwidth(16)

    # show images and set titles
    ax1.imshow(img_scaled[...,0])
    ax2.imshow(pred, cmap="gray", vmin=0, vmax=1)
    ax3.imshow(mask[0,...,0])

    ax1.set_title('Image')
    ax2.set_title('Prediction')
    ax3.set_title('Label Mask')

# %% [markdown]
# ## Create a CZANN/CZSEG from the trained Keras model
# In this section we export the trained model to the CZANN format using the czmodel library and some additional meta data all possible parameter choices are described in the [ANN model specification](https://pypi.org/project/czmodel/).

# %% [markdown]
# ### Define Meta Data
# We first define the meta data needed to run the model within the Intellesis infrastructure. The `czmodel` package offers a named tuple `ModelMetadata` that allows to either parse as JSON file as described in the [specification document](https://pypi.org/project/czmodel/) or to directly specify the parameters as shown below.

# %% [markdown]
# ### Create a Model Specification Object
# The export functions provided by the `czmodel` package expect a `ModelSpec` tuple that features the Keras model to be exported, the corresponding model meda data and optionally a license file for the model.
#
# Therefore, we wrap our model and the `model_metadata` instance into a `ModelSpec` object.

# %%
# Define dimensions - ZEN Intellesis requires fully defined spatial dimensions in the meta data of the CZANN model.
# The ZEN TilingClient uses the input shape in the meta data to infer the tile size to pass an image to the inferencer.
# Important: The tile size has to be chosen s.t. inference is possible with the minimum hardware requirements of Intellesis
# Optional: Define target spatial dimensions of the model for inference.
input_size = 1024

# Define the model metadata
model_metadata = ModelMetadata(
    input_shape=[input_size, input_size, 1],
    output_shape=[input_size, input_size, 2],
    model_type=ModelType.SINGLE_CLASS_SEMANTIC_SEGMENTATION,
    classes=["Background", "Nucleus"],
    model_name="Simple_Nuclei_SegmentationModel",
    min_overlap=[8, 8],
)
model_spec = ModelSpec(
    model=model,
    model_metadata=model_metadata,
    license_file=None
)

model_metadata_legacy = LegacyModelMetadata(
    name="Simple_Nuclei_SegmentationModel_Legacy",
    classes=["Background", "Nucleus"],
    pixel_types="Gray16",
    color_handling="SplitRgb",
    border_size=8,
)
model_spec_legacy = LegacyModelSpec(
    model=model,
    model_metadata=model_metadata_legacy,
    license_file=None
)

# Define pre-processing
preprocessing = [
    Shift(-images_mean),
    Scale(1.0 / images_std)
]
preprocessing_legacy = [ # Mean and sandard deviation must be scaled according to the bit depth of the input images
    Shift(-images_mean * (2**16 - 1)),
    Scale((2**16 - 1) / images_std)
]

# %% [markdown]
# ### Perform model export into *.czann / *.czseg file format
#
# The converters from the `czmodel` library offers two functions to perform the actual export.
#
# * `convert_from_json_spec` allows to provide a JSON file containing all the information of a ModelSpec object and converts a model in SavedModel format on disk to a `.czann` / `.czseg` file that can be loaded with ZEN.
# * `convert_from_model_spec` expects a `ModelSpec` object, an output path and name and optionally target spatial dimensions for the expected input of the exported model. From this information it creates a `.czann` / `.czseg` file containing the specified model.
#
# Currently, `czmodel` offers two converters:
# * DefaultConverter: Converts a model to a *.czann file.
# * LegacyConverter: Converts a model to a *.czseg file (legacy format).

# %%
DefaultConverter().convert_from_model_spec(
    model_spec=model_spec, 
    output_path='./', 
    output_name='simple_nuclei_segmodel',
    spatial_dims=(input_size, input_size),
    preprocessing=preprocessing
)
# Out:
# '--tag' not specified for saved_model. Using --tag serve
# '--signature_def' not specified, using first signature: serving_default

# %%
LegacyConverter().convert_from_model_spec(
    model_spec=model_spec_legacy, 
    output_path='./', 
    output_name='simple_nuclei_segmodel_legacy',
    spatial_dims=(input_size, input_size),
    preprocessing=preprocessing_legacy
)
# Out:
# '--tag' not specified for saved_model. Using --tag serve
# '--signature_def' not specified, using first signature: serving_default

# %% [markdown]
# ## Remarks
# The generated .czann and .czseg files can be directly loaded into ZEN Intellesis to perform segmentation tasks with the trained model.
# If there is already a trained model in SavedModel format present on disk, it can also be converted by providing the path to the saved model directory instead of a Keras `Model` object. The `czmodel` library will implicitly load the model from the provided path.

# %% [markdown]
# The `czmodel` library also provides a `convert_from_json_spec` function that accepts a JSON file with the above mentioned meta data behind the key `ModelMetadata` which will implicitly be deserialized into a `ModelMetadata` object, the model path and optionally a license file:
# ```json
# {
#     "ModelMetadata": {
#         "Type": "SingleClassSemanticSegmentation",
#         "Classes": ["Background", "Nucleus"],
#         "InputShape": [1024, 1024, 1],
#         "OutputShape": [1024, 1024, 2],
#         "ModelName": "Nuclei Segmentation Model From JSON",
#         "MinOverlap": [8, 8]
#     },
#     "ModelPath": "./saved_tf2_model_output/",
#     "LicenseFile": null
# }
# ```
#
# This information can be copied to a file e.g. in the current working directory `./model_conversion_spec.json` that also contains the trained model in SavedModel format e.g. generated by the following line:

# %%
# save the trained TF2.SavedModel as a folder structure
# The folder + the JSON file can be also used to import the model in ZEN

model.save('./saved_tf2_model_output/')

# %%
# This is an additional way to create a CZANN from a saved TF2 model on disk + JSON file.
# The currently recommended way to to create the CZANN directly by using czmodel.convert_from_model_spec
# the path to the TF2.SavedModel folder is defined in the JSON shown above

DefaultConverter().convert_from_json_spec(
    model_spec_path='model_conversion_spec.json',
    output_path='./',
    output_name = 'simple_nuclei_segmodel_from_json',
    spatial_dims=(input_size, input_size),
    preprocessing=preprocessing
)
# Out:
# '--tag' not specified for saved_model. Using --tag serve
# '--signature_def' not specified, using first signature: serving_default

# %% [markdown]
# ## User the *.czann to run a prediction
#
# Now we use the created *.czann file to run a simple prediction to demostrates the usage of such models trained somewhere else. One one woukld be to train a *.czann file on the www.apeer.com platform.

# %%
from _onnx_inference import OnnxInferencer

# get the sample images
sample_images = sorted([os.path.join(IMAGES_FOLDER, f) for f in os.listdir(IMAGES_FOLDER)
                        if os.path.isfile(os.path.join(IMAGES_FOLDER, f))])

# get the maks
sample_masks = sorted([os.path.join(MASKS_FOLDER, f) for f in os.listdir(MASKS_FOLDER)
                       if os.path.isfile(os.path.join(MASKS_FOLDER, f))])

czann_file = os.path.join(os.getcwd(), "simple_nuclei_segmodel.czann")

# %%
# create a simple function to run the prediction on a single image

def predict_one(sess, array2d):

    array2d = array2d[np.newaxis]
    input_name = sess.get_inputs()[0].name
    output_name = sess.get_outputs()[0].name

    # ONNX can only handle float32
    array2d = array2d.astype(np.float32)
    input_dict = {input_name: array2d}
    result = sess.run([output_name], input_dict)[0]

    return result[0]

# %% [markdown]
# ### Unpacking CZANN files
#
# The czmodel library offers functionality to unpack existing CZANN/CZSEG models. For a given .czann or .czseg model it is possible to extract the underlying ANN model to a specified folder and retrieve the corresponding meta-data as instances of the meta-data classes defined in the czmodel library.
#
# For CZANN files:
#
# ```python
# from czmodel.convert import DefaultConverter
# from pathlib import Path
#
# model_metadata, model_path = DefaultConverter().unpack_model(model_file='Path of the .czann file', target_dir=Path('Output Path'))
# ```

# %%
# extract the model information and path and to the prediction
with tempfile.TemporaryDirectory() as temp_path:

    # get the model metadata and the path
    model_metadata, model_path = DefaultConverter().unpack_model(model_file=czann_file, target_dir=Path(temp_path))

    # get model metadata as dictionary
    model_metadata_dict = model_metadata._asdict()
    for k,v in model_metadata_dict.items():
        print(k, "=", v)

    # get the input shape
    shp = model_metadata.input_shape

    # create an ONNX session and get the input shape
    # use either "CUDAExecutionProvider" or "CPUExecutionProvider"]
    sess = onnx_rt.InferenceSession(str(model_path), providers=["CPUExecutionProvider"])
# Out:
# model_type = ModelType.SINGLE_CLASS_SEMANTIC_SEGMENTATION
# input_shape = [1024, 1024, 1]
# output_shape = [1024, 1024, 2]
# model_id = 34c8660b-2db4-425d-a16d-d6e803171c9a
# min_overlap = [8, 8]
# classes = ['Background', 'Nucleus']
# model_name = Simple_Nuclei_SegmentationModel

# %%
# imort additional modules to read images
from skimage import io
import random

# %%
# just re-execute the cell to display a different image

# select an a random image
id = random.randint(0, len(sample_images))

# read images and scale
img = io.imread(sample_images[id])/(2**16 - 1)
mask = io.imread(sample_masks[id])

# cut input to fit the model
img = img[0: shp[0], 0:shp[1]]
mask = mask[0: shp[0], 0:shp[1]]

# run the actual prediction
pred = predict_one(sess, img[..., np.newaxis])

fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
fig.set_figwidth(16)

# show images and set titles
ax1.imshow(img, vmin=0, vmax=0.05)
ax2.imshow(pred[..., 1], cmap="gray")
ax3.imshow(mask)

ax1.set_title('Image')
ax2.set_title('Prediction')
ax3.set_title('Label Mask')
# Out:
# Text(0.5, 1.0, 'Label Mask')

# %% [markdown]
# Use the commands below from a terminal to present the notebook as a slideshow.
#
# `
# jupyter nbconvert SingleClassSemanticSegmentation_3_0_0.ipynb --to slides --post serve
#     --SlidesExporter.reveal_theme=serif
#     --SlidesExporter.reveal_scroll=True
#     --SlidesExporter.reveal_transition=none
# `
